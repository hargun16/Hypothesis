# %% [markdown]
# Ans1.  The null hypothesis (H₀) is a statement that there is no effect, no difference, or no relationship. The value is important set an argument, set a baseline and helps calculate the statistics
#
#
# Ans2. The probability of rejecting the null value hypothesis. Common value used is 5% or 0.05.
#
#
# Ans3. Typel error is when a true null value is wrongfully rejected "fale positive"
# Typell error when a false null value is wrongfully not rejected "false negative"
#
#
# Ans4.  ONE TAILED TEST is done in one direction.
# eg: say we have to check the improvement in sales from sample A to Sample B. This test only focuses on improvement which means it is one tailed test towards right.
#
# TWO TAILED TEST is done in both the directions negative and positive
# eg: we need to test that h(0) averge height in town is 168cm. h(1) survay of 50 individual shows mean is not h(0). In this case the new value could be more than 168 or less than 168.
#
#
# Ans5.  h(0)= 10min,
# h(1) not= 10min, a=0.05, sd=3min, CALCULATING T= mean-h(0)/sd.√N, 12-10/3.√9= 2. DF= N-1, therefore df=8, tcritical = ±2.306 from t table. There we fail to reject h(0)
#
#
# Ans6.  Z TEST is done when the Standard deviation is not certain or more than 30, T Test is done when satndard deviation is less than 30.
#
#
# Ans7.  h(0)=0, h(1)= not 0 improvement. Taking the difference of both mean of both before and after that is 56.
#
#
# Ans8.  h(0)= independent to gender, h(1)= not independent to gender.
#
#
#
# E=Row total*Column total/100, MaleA: (70*50)/100 = 35
# MaleB: 35
# FemaleA: 15
# FemaleB: 15
#
# CHI TEST
# Male A = 0.714
# Male B= 0.714
# Female A 1.667
# Female B= 1.667
# TOTAL= 4.762
#
# DF=n-1, 2-1=1
# T table = 12.75
# result reject h(0)
